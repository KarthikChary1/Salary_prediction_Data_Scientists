# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist           53-91
# 1  Healthcare Data Scientist          63-112
# 2             Data Scientist           80-90
# 3             Data Scientist           56-97
# 4             Data Scientist          86-143
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# 2                                KnowBe4\r\n4.8   Clearwater, FL
# ...

# %%
df["Job Title"].unique()
# Out:
# array(['Data Scientist', 'Healthcare Data Scientist',
#        'Research Scientist', 'Staff Data Scientist - Technology',
#        'Data Analyst', 'Data Engineer I', 'Scientist I/II, Biology',
#        'Customer Data Scientist',
#        'Data Scientist - Health Data Analytics',
#        'Senior Data Scientist / Machine Learning',
#        'Data Scientist - Quantitative', 'Digital Health Data Scientist',
#        'Associate Data Analyst', 'Clinical Data Scientist',
#        'Data Scientist / Machine Learning Expert', 'Web Data Analyst',
#        'Senior Data Scientist', 'Data Engineer',
#        'Data Scientist - Algorithms & Inference', 'Scientist',
#        'Lead Data Scientist', 'Spectral Scientist/Engineer',
#        'College Hire - Data Scientist - Open to December 2019 Graduates',
#        'Data Scientist, Office of Data Science', 'Data Science Analyst',
#        'Senior Risk Data Scientist',
#        'Data Scientist in Artificial Intelligence Early Career',
# ...

# %%
#senior
#sr
#jr
def job_simplifier(title):
    if "data scientist" in title.lower():
        return "data scientist"
    elif "analyst" in title.lower():
        return "data analyst"
    elif "engineer" in title.lower():
        return "data engineer"
    elif "machine learning" in title.lower():
        return "mle"
    elif "director" in title.lower():
        return "director"
    elif "manager" in title.lower():
        return "manager"
    else:
        return "na"

# %%
def seniority(title):
    if "sr" in title.lower() or "sr." in title.lower() or "senior" in title.lower() or "principal" in title.lower() or "lead" in title.lower():
        return "senior"
    elif "jr" in title.lower() or "junior" in title.lower() or "jr." in title.lower():
        return "junior"
    else:
        return "na"

# %%
df["job_simple"]=df["Job Title"].apply(job_simplifier)

# %%
df["job_simple"].value_counts()
# Out:
# data scientist    279
# na                161
# data engineer     153
# data analyst      103
# manager            22
# director           14
# mle                10
# Name: job_simple, dtype: int64

# %%
df[df.job_simple=="na"]["Job Title"].unique()
# Out:
# array(['Research Scientist', 'Scientist I/II, Biology', 'Scientist',
#        'R&D Data Analysis Scientist', 'Analytics Consultant',
#        'Data Management Specialist', 'Sr. Scientist II', 'Data Modeler',
#        'Project Scientist', 'Associate Scientist',
#        'Scientist 2, QC Viral Vector',
#        'Senior Research Scientist - Embedded System Development for DevOps',
#        'Pricipal Scientist Molecular and cellular biologist',
#        'Senior Scientist - Neuroscience', 'Medical Lab Scientist',
#        'Scientist, Analytical Development',
#        'Sr. Scientist - Digital & Image Analysis/Computational Pathology',
#        'Principal Scientist - Immunologist',
#        'MED TECH/LAB SCIENTIST - LABORATORY',
#        'Sr. Scientist, Quantitative Translational Sciences',
#        'VP, Data Science', 'PV Scientist',
#        'Principal Scientist, Chemistry & Immunology',
#        'Scientist/Senior Scientist, Autoimmune',
# ...

# %%
df["seniority"]=df["Job Title"].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        519
# senior    220
# junior      3
# Name: seniority, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'emp_provided', 'min_sal', 'max_sal', 'avg_sal',
#        'company_text', 'job_state', 'same_loc_head', 'Years_of_estd', 'python',
#        'excel', 'spark', 'tableau', 'rstudio', 'sas', 'job_simple',
#        'seniority'],
#       dtype='object')

# %%
df.groupby("job_state")["job_state"].count()
# Out:
# job_state
#  AL               8
#  AZ               9
#  CA             151
#  CO              11
#  CT               5
#  DC              11
#  DE               6
#  FL              16
#  GA               6
#  IA               5
#  ID               2
#  IL              40
#  IN              10
#  KS               3
#  KY               6
#  LA               4
#  Los Angeles      1
#  MA             103
#  MD              35
#  MI               6
#  MN               2
#  MO               9
#  NC              21
#  NE               4
#  NJ              17
#  NM               3
#  NY              72
#  OH              14
#  OR               4
#  PA              33
#  RI               1
#  SC               1
#  TN              13
#  TX              28
#  UT              10
#  VA              41
#  WA              21
#  WI              10
# Name: job_state, dtype: int64

# %%
df.shape
# Out:
# (742, 31)

# %%
df.job_state.unique()
# Out:
# array([' NM', ' MD', ' FL', ' WA', ' NY', ' TX', ' CA', ' VA', ' MA',
#        ' NJ', ' CO', ' IL', ' KY', ' OR', ' CT', ' MI', ' DC', ' OH',
#        ' AL', ' MO', ' PA', ' GA', ' IN', ' LA', ' WI', ' NC', ' AZ',
#        ' NE', ' MN', ' Los Angeles', ' UT', ' TN', ' DE', ' ID', ' RI',
#        ' IA', ' SC', ' KS'], dtype=object)

# %%
df1=df.copy()

# %%
df1["job_state"]=df.job_state.apply(lambda x: "CA" if "los angeles" in x.strip().lower() else x)

# %%
df1.job_state.unique()
# Out:
# array([' NM', ' MD', ' FL', ' WA', ' NY', ' TX', ' CA', ' VA', ' MA',
#        ' NJ', ' CO', ' IL', ' KY', ' OR', ' CT', ' MI', ' DC', ' OH',
#        ' AL', ' MO', ' PA', ' GA', ' IN', ' LA', ' WI', ' NC', ' AZ',
#        ' NE', ' MN', 'CA', ' UT', ' TN', ' DE', ' ID', ' RI', ' IA',
#        ' SC', ' KS'], dtype=object)

# %%
pd.set_option('display.max_columns', None)

# %%
df1.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist           53-91
# 1  Healthcare Data Scientist          63-112
# 2             Data Scientist           80-90
# 3             Data Scientist           56-97
# 4             Data Scientist          86-143
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# 2                                KnowBe4\r\n4.8   Clearwater, FL
# ...

# %%
df1.hourly.dtype
# Out:
# dtype('int64')

# %%
df1[df1.hourly==1]["Salary Estimate"]
# Out:
# 165    17-24
# 177    21-34
# 197    18-25
# 202    21-34
# 210    15-25
# 246    17-24
# 271    21-34
# 337    18-25
# 345    24-39
# 357    21-34
# 363    25-28
# 408    21-29
# 409    10-17
# 492    18-25
# 509    24-39
# 533    21-34
# 542    25-28
# 617    21-29
# 618    10-17
# 645    27-47
# 666    18-25
# 682    24-39
# 711    21-34
# 724    25-28
# Name: Salary Estimate, dtype: object

# %%
df1["min_sal"]=df.apply(lambda x: x["min_sal"]*2 if x["hourly"]==1 else x["min_sal"],axis=1)

# %%
df1[df1.hourly==1]["min_sal"]
# Out:
# 165    34
# 177    42
# 197    36
# 202    42
# 210    30
# 246    34
# 271    42
# 337    36
# 345    48
# 357    42
# 363    50
# 408    42
# 409    20
# 492    36
# 509    48
# 533    42
# 542    50
# 617    42
# 618    20
# 645    54
# 666    36
# 682    48
# 711    42
# 724    50
# Name: min_sal, dtype: int64

# %%
df1["max_sal"]=df.apply(lambda x: x["max_sal"]*2 if x["hourly"]==1 else x["max_sal"],axis=1)

# %%
df1[df1.hourly==1]["max_sal"]
# Out:
# 165    48
# 177    68
# 197    50
# 202    68
# 210    50
# 246    48
# 271    68
# 337    50
# 345    78
# 357    68
# 363    56
# 408    58
# 409    34
# 492    50
# 509    78
# 533    68
# 542    56
# 617    58
# 618    34
# 645    94
# 666    50
# 682    78
# 711    68
# 724    56
# Name: max_sal, dtype: int64

# %%
df1["len_of_desc"]=df["Job Description"].apply(lambda x: int(len(x)) if x!="-1" else 0)

# %%
df1.len_of_desc
# Out:
# 0      2555
# 1      4828
# 2      3495
# 3      3926
# 4      2748
#        ...
# 737    6219
# 738    6167
# 739    3107
# 740    1678
# 741    3710
# Name: len_of_desc, Length: 742, dtype: int64

# %%
df1.to_csv("cleaned_data_2.csv",index=False)
